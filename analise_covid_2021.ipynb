# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import plotly.express as xp

# %% [markdown]
# # 1. BASES DE DADOS

# %% [markdown]
# ### 1.1. Base de dados 2021.1:

# %%
b2021_1 = pd.read_csv('HIST_PAINEL_COVIDBR_2021_Parte1_07nov2022.csv', sep=';')

# %%
b2021_1
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1017034  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017035  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017036  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017037  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017038  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
b2021_1 = b2021_1.loc[(b2021_1['regiao']=='Nordeste')]
b2021_1
# Out:
#           regiao estado    municipio  coduf    codmun  codRegiaoSaude  \
# 1448    Nordeste     MA          NaN     21       NaN             NaN
# 1449    Nordeste     MA          NaN     21       NaN             NaN
# 1450    Nordeste     MA          NaN     21       NaN             NaN
# 1451    Nordeste     MA          NaN     21       NaN             NaN
# 1452    Nordeste     MA          NaN     21       NaN             NaN
# ...          ...    ...          ...    ...       ...             ...
# 413399  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 413400  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 413401  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 413402  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 413403  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
b2021_1 = b2021_1[b2021_1['municipio'].isna()]

# %%
b2021_1
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1448    Nordeste     MA       NaN     21       NaN             NaN
# 1449    Nordeste     MA       NaN     21       NaN             NaN
# 1450    Nordeste     MA       NaN     21       NaN             NaN
# 1451    Nordeste     MA       NaN     21       NaN             NaN
# 1452    Nordeste     MA       NaN     21       NaN             NaN
# ...          ...    ...       ...    ...       ...             ...
# 337922  Nordeste     BA       NaN     29  290000.0             NaN
# 337923  Nordeste     BA       NaN     29  290000.0             NaN
# 337924  Nordeste     BA       NaN     29  290000.0             NaN
# 337925  Nordeste     BA       NaN     29  290000.0             NaN
# 337926  Nordeste     BA       NaN     29  290000.0             NaN
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 1448               NaN  2021-01-01         53         7075181.0
# ...

# %% [markdown]
# ### 1.2. Base de dados 2021.2:

# %%
b2021_2 = pd.read_csv('HIST_PAINEL_COVIDBR_2021_Parte2_07nov2022.csv', sep=';')

# %%
b2021_2
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1033891  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1033892  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1033893  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1033894  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1033895  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
b2021_2 = b2021_2.loc[(b2021_2['regiao']=='Nordeste')]
b2021_2
# Out:
#           regiao estado    municipio  coduf    codmun  codRegiaoSaude  \
# 1472    Nordeste     MA          NaN     21       NaN             NaN
# 1473    Nordeste     MA          NaN     21       NaN             NaN
# 1474    Nordeste     MA          NaN     21       NaN             NaN
# 1475    Nordeste     MA          NaN     21       NaN             NaN
# 1476    Nordeste     MA          NaN     21       NaN             NaN
# ...          ...    ...          ...    ...       ...             ...
# 420251  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 420252  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 420253  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 420254  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
# 420255  Nordeste     BA  Xique-Xique     29  293360.0         29010.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
b2021_2 = b2021_2[b2021_2['municipio'].isna()]
b2021_2
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1472    Nordeste     MA       NaN     21       NaN             NaN
# 1473    Nordeste     MA       NaN     21       NaN             NaN
# 1474    Nordeste     MA       NaN     21       NaN             NaN
# 1475    Nordeste     MA       NaN     21       NaN             NaN
# 1476    Nordeste     MA       NaN     21       NaN             NaN
# ...          ...    ...       ...    ...       ...             ...
# 343523  Nordeste     BA       NaN     29  290000.0             NaN
# 343524  Nordeste     BA       NaN     29  290000.0             NaN
# 343525  Nordeste     BA       NaN     29  290000.0             NaN
# 343526  Nordeste     BA       NaN     29  290000.0             NaN
# 343527  Nordeste     BA       NaN     29  290000.0             NaN
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 1472               NaN  2021-07-01         26         7075181.0
# ...

# %% [markdown]
# # 2. TRATAMENTO DOS DADOS

# %% [markdown]
# ## 2.1. 2021.1

# %% [markdown]
# ### 2.1.1. 2021.1: dados do último dia do semestre (30 de junho)

# %%
b2021_1_ultimo_dia = b2021_1.loc[(b2021_1['data']=='2021-06-30')]
b2021_1_ultimo_dia
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1628    Nordeste     MA       NaN     21       NaN             NaN
# 1809    Nordeste     PI       NaN     22       NaN             NaN
# 1990    Nordeste     CE       NaN     23       NaN             NaN
# 2171    Nordeste     RN       NaN     24       NaN             NaN
# 2352    Nordeste     PB       NaN     25       NaN             NaN
# 2533    Nordeste     PE       NaN     26       NaN             NaN
# 2714    Nordeste     AL       NaN     27       NaN             NaN
# 2895    Nordeste     SE       NaN     28       NaN             NaN
# 3076    Nordeste     BA       NaN     29       NaN             NaN
# 87241   Nordeste     MA       NaN     21  210000.0             NaN
# 126699  Nordeste     PI       NaN     22  220000.0             NaN
# 167424  Nordeste     CE       NaN     23  230000.0             NaN
# 200909  Nordeste     RN       NaN     24  240000.0             NaN
# ...

# %%
b2021_1_ultimo_dia = b2021_1_ultimo_dia[b2021_1_ultimo_dia['codmun'].isna()]
b2021_1_ultimo_dia
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 1628  Nordeste     MA       NaN     21     NaN             NaN
# 1809  Nordeste     PI       NaN     22     NaN             NaN
# 1990  Nordeste     CE       NaN     23     NaN             NaN
# 2171  Nordeste     RN       NaN     24     NaN             NaN
# 2352  Nordeste     PB       NaN     25     NaN             NaN
# 2533  Nordeste     PE       NaN     26     NaN             NaN
# 2714  Nordeste     AL       NaN     27     NaN             NaN
# 2895  Nordeste     SE       NaN     28     NaN             NaN
# 3076  Nordeste     BA       NaN     29     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 1628             NaN  2021-06-30         26         7075181.0        317446.0
# 1809             NaN  2021-06-30         26         3273227.0        295781.0
# 1990             NaN  2021-06-30         26         9132078.0        885980.0
# ...

# %%
b2021_1_ultimo_dia = b2021_1_ultimo_dia.sort_values(by='estado')
b2021_1_ultimo_dia
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 2714  Nordeste     AL       NaN     27     NaN             NaN
# 3076  Nordeste     BA       NaN     29     NaN             NaN
# 1990  Nordeste     CE       NaN     23     NaN             NaN
# 1628  Nordeste     MA       NaN     21     NaN             NaN
# 2352  Nordeste     PB       NaN     25     NaN             NaN
# 2533  Nordeste     PE       NaN     26     NaN             NaN
# 1809  Nordeste     PI       NaN     22     NaN             NaN
# 2171  Nordeste     RN       NaN     24     NaN             NaN
# 2895  Nordeste     SE       NaN     28     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 2714             NaN  2021-06-30         26         3337357.0        216717.0
# 3076             NaN  2021-06-30         26        14873064.0       1124994.0
# 1990             NaN  2021-06-30         26         9132078.0        885980.0
# ...

# %%
b2021_1_ultimo_dia = b2021_1_ultimo_dia.drop(columns=[
    'coduf', 
    'codmun', 
    'codRegiaoSaude', 
    'nomeRegiaoSaude', 
    'Recuperadosnovos', 
    'emAcompanhamentoNovos', 
    'interior/metropolitana',
    'semanaEpi'])
b2021_1_ultimo_dia
# Out:
#         regiao estado municipio        data  populacaoTCU2019  casosAcumulado  \
# 2714  Nordeste     AL       NaN  2021-06-30         3337357.0        216717.0
# 3076  Nordeste     BA       NaN  2021-06-30        14873064.0       1124994.0
# 1990  Nordeste     CE       NaN  2021-06-30         9132078.0        885980.0
# 1628  Nordeste     MA       NaN  2021-06-30         7075181.0        317446.0
# 2352  Nordeste     PB       NaN  2021-06-30         4018127.0        396442.0
# 2533  Nordeste     PE       NaN  2021-06-30         9557071.0        550292.0
# 1809  Nordeste     PI       NaN  2021-06-30         3273227.0        295781.0
# 2171  Nordeste     RN       NaN  2021-06-30         3506853.0        340165.0
# 2895  Nordeste     SE       NaN  2021-06-30         2298696.0        263512.0
#
#       casosNovos  obitosAcumulado  obitosNovos
# 2714         516             5340           20
# 3076        1683            24012          106
# ...

# %% [markdown]
# ## 2.2 2021.2

# %% [markdown]
# ### 2.2.1. 2021.2: dados do último dia do semestre (31 de dezembro)

# %%
b2021_2_ultimo_dia = b2021_2.loc[(b2021_2['data']=='2021-12-31')]
b2021_2_ultimo_dia
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1655    Nordeste     MA       NaN     21       NaN             NaN
# 1839    Nordeste     PI       NaN     22       NaN             NaN
# 2023    Nordeste     CE       NaN     23       NaN             NaN
# 2207    Nordeste     RN       NaN     24       NaN             NaN
# 2391    Nordeste     PB       NaN     25       NaN             NaN
# 2575    Nordeste     PE       NaN     26       NaN             NaN
# 2759    Nordeste     AL       NaN     27       NaN             NaN
# 2943    Nordeste     SE       NaN     28       NaN             NaN
# 3127    Nordeste     BA       NaN     29       NaN             NaN
# 88687   Nordeste     MA       NaN     21  210000.0             NaN
# 128799  Nordeste     PI       NaN     22  220000.0             NaN
# 170199  Nordeste     CE       NaN     23  230000.0             NaN
# 204239  Nordeste     RN       NaN     24  240000.0             NaN
# ...

# %%
b2021_2_ultimo_dia = b2021_2_ultimo_dia[b2021_2_ultimo_dia['codmun'].isna()]
b2021_2_ultimo_dia
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 1655  Nordeste     MA       NaN     21     NaN             NaN
# 1839  Nordeste     PI       NaN     22     NaN             NaN
# 2023  Nordeste     CE       NaN     23     NaN             NaN
# 2207  Nordeste     RN       NaN     24     NaN             NaN
# 2391  Nordeste     PB       NaN     25     NaN             NaN
# 2575  Nordeste     PE       NaN     26     NaN             NaN
# 2759  Nordeste     AL       NaN     27     NaN             NaN
# 2943  Nordeste     SE       NaN     28     NaN             NaN
# 3127  Nordeste     BA       NaN     29     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 1655             NaN  2021-12-31         52         7075181.0          370645
# 1839             NaN  2021-12-31         52         3273227.0          334440
# 2023             NaN  2021-12-31         52         9132078.0          956325
# ...

# %%
b2021_2_ultimo_dia = b2021_2_ultimo_dia.sort_values(by='estado')
b2021_2_ultimo_dia
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 2759  Nordeste     AL       NaN     27     NaN             NaN
# 3127  Nordeste     BA       NaN     29     NaN             NaN
# 2023  Nordeste     CE       NaN     23     NaN             NaN
# 1655  Nordeste     MA       NaN     21     NaN             NaN
# 2391  Nordeste     PB       NaN     25     NaN             NaN
# 2575  Nordeste     PE       NaN     26     NaN             NaN
# 1839  Nordeste     PI       NaN     22     NaN             NaN
# 2207  Nordeste     RN       NaN     24     NaN             NaN
# 2943  Nordeste     SE       NaN     28     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 2759             NaN  2021-12-31         52         3337357.0          242080
# 3127             NaN  2021-12-31         52        14873064.0         1270858
# 2023             NaN  2021-12-31         52         9132078.0          956325
# ...

# %%
b2021_2_ultimo_dia = b2021_2_ultimo_dia.drop(columns=[
    'coduf', 
    'codmun', 
    'codRegiaoSaude', 
    'nomeRegiaoSaude', 
    'Recuperadosnovos', 
    'emAcompanhamentoNovos', 
    'interior/metropolitana',
    'semanaEpi'])
b2021_2_ultimo_dia
# Out:
#         regiao estado municipio        data  populacaoTCU2019  casosAcumulado  \
# 2759  Nordeste     AL       NaN  2021-12-31         3337357.0          242080
# 3127  Nordeste     BA       NaN  2021-12-31        14873064.0         1270858
# 2023  Nordeste     CE       NaN  2021-12-31         9132078.0          956325
# 1655  Nordeste     MA       NaN  2021-12-31         7075181.0          370645
# 2391  Nordeste     PB       NaN  2021-12-31         4018127.0          464335
# 2575  Nordeste     PE       NaN  2021-12-31         9557071.0          645681
# 1839  Nordeste     PI       NaN  2021-12-31         3273227.0          334440
# 2207  Nordeste     RN       NaN  2021-12-31         3506853.0          387202
# 2943  Nordeste     SE       NaN  2021-12-31         2298696.0          278530
#
#       casosNovos  obitosAcumulado  obitosNovos
# 2759          40             6383            0
# 3127         377            27506            5
# ...

# %% [markdown]
# ## 2.3 2021

# %% [markdown]
# ### 2.3.1. 2021: informações mensais (primeiro dia dos meses)

# %%
jan = b2021_1.loc[b2021_1['data']=='2021-01-01']
jan = jan.loc[jan['codmun'].isna()].sort_values(by='estado')

fev = b2021_1.loc[b2021_1['data']=='2021-02-01']
fev = fev.loc[fev['codmun'].isna()].sort_values(by='estado')

mar = b2021_1.loc[b2021_1['data']=='2021-03-01']
mar = mar.loc[mar['codmun'].isna()].sort_values(by='estado')

abr = b2021_1.loc[b2021_1['data']=='2021-04-01']
abr = abr.loc[abr['codmun'].isna()].sort_values(by='estado')

mai = b2021_1.loc[b2021_1['data']=='2021-05-01']
mai = mai.loc[mai['codmun'].isna()].sort_values(by='estado')

jun = b2021_1.loc[b2021_1['data']=='2021-06-01']
jun = jun.loc[jun['codmun'].isna()].sort_values(by='estado')

jul = b2021_2.loc[b2021_2['data']=='2021-07-01']
jul = jul.loc[jul['codmun'].isna()].sort_values(by='estado')

ago = b2021_2.loc[b2021_2['data']=='2021-08-01']
ago = ago.loc[ago['codmun'].isna()].sort_values(by='estado')

setb = b2021_2.loc[b2021_2['data']=='2021-09-01']
setb = setb.loc[setb['codmun'].isna()].sort_values(by='estado')

out = b2021_2.loc[b2021_2['data']=='2021-10-01']
out = out.loc[out['codmun'].isna()].sort_values(by='estado')

nov = b2021_2.loc[b2021_2['data']=='2021-11-01']
nov = nov.loc[nov['codmun'].isna()].sort_values(by='estado')

dez = b2021_2.loc[b2021_2['data']=='2021-12-01']
dez = dez.loc[dez['codmun'].isna()].sort_values(by='estado')

b2021_meses = pd.concat([
    jan, 
    fev, 
    mar, 
    abr, 
    mai, 
    jun, 
    jul, 
    ago, 
    setb, 
    out, 
    nov, 
    dez], axis=0)

b2021_meses = b2021_meses.sort_values('data')

b2021_meses
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 2534  Nordeste     AL       NaN     27     NaN             NaN
# 2896  Nordeste     BA       NaN     29     NaN             NaN
# 1810  Nordeste     CE       NaN     23     NaN             NaN
# 1448  Nordeste     MA       NaN     21     NaN             NaN
# 2172  Nordeste     PB       NaN     25     NaN             NaN
# ...        ...    ...       ...    ...     ...             ...
# 1625  Nordeste     MA       NaN     21     NaN             NaN
# 2361  Nordeste     PB       NaN     25     NaN             NaN
# 2545  Nordeste     PE       NaN     26     NaN             NaN
# 1809  Nordeste     PI       NaN     22     NaN             NaN
# 2913  Nordeste     SE       NaN     28     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 2534             NaN  2021-01-01         53         3337357.0        105091.0
# ...

# %%
b2021_meses = b2021_meses.drop(columns=[
    'semanaEpi',
    'regiao',
    'municipio', 
    'populacaoTCU2019',
    'coduf', 
    'codmun', 
    'codRegiaoSaude', 
    'nomeRegiaoSaude', 
    'Recuperadosnovos', 
    'emAcompanhamentoNovos', 
    'interior/metropolitana'])

b2021_meses
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2534     AL  2021-01-01        105091.0         273             2496
# 2896     BA  2021-01-01        494684.0        1284             9159
# 1810     CE  2021-01-01        335992.0         901             9993
# 1448     MA  2021-01-01        200959.0          21             4506
# 2172     PB  2021-01-01        167062.0         578             3680
# ...     ...         ...             ...         ...              ...
# 1625     MA  2021-12-01        365338.0         290            10297
# 2361     PB  2021-12-01        460909.0         329             9532
# 2545     PE  2021-12-01        640158.0         421            20253
# 1809     PI  2021-12-01        331612.0          71             7194
# 2913     SE  2021-12-01        278266.0          41             6044
#
#       obitosNovos
# 2534            7
# 2896           30
# 1810            3
# 1448            6
# 2172            8
# ...           ...
# ...

# %% [markdown]
# ### 2.3.2. 2021: informações diárias

# %%
b2021 = pd.concat([
    b2021_1,
    b2021_2
], axis=0)

b2021 = b2021[b2021['codmun'].isna()].sort_values(by='data')

b2021
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 1448  Nordeste     MA       NaN     21     NaN             NaN
# 2715  Nordeste     SE       NaN     28     NaN             NaN
# 1810  Nordeste     CE       NaN     23     NaN             NaN
# 1991  Nordeste     RN       NaN     24     NaN             NaN
# 2534  Nordeste     AL       NaN     27     NaN             NaN
# ...        ...    ...       ...    ...     ...             ...
# 2759  Nordeste     AL       NaN     27     NaN             NaN
# 2023  Nordeste     CE       NaN     23     NaN             NaN
# 1839  Nordeste     PI       NaN     22     NaN             NaN
# 2391  Nordeste     PB       NaN     25     NaN             NaN
# 3127  Nordeste     BA       NaN     29     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 1448             NaN  2021-01-01         53         7075181.0        200959.0
# ...

# %%
b2021 = b2021.drop(columns=[
    'coduf', 
    'codmun', 
    'codRegiaoSaude', 
    'nomeRegiaoSaude', 
    'Recuperadosnovos', 
    'emAcompanhamentoNovos', 
    'interior/metropolitana',
    'semanaEpi'
])

b2021
# Out:
#         regiao estado municipio        data  populacaoTCU2019  casosAcumulado  \
# 1448  Nordeste     MA       NaN  2021-01-01         7075181.0        200959.0
# 2715  Nordeste     SE       NaN  2021-01-01         2298696.0        113544.0
# 1810  Nordeste     CE       NaN  2021-01-01         9132078.0        335992.0
# 1991  Nordeste     RN       NaN  2021-01-01         3506853.0        118353.0
# 2534  Nordeste     AL       NaN  2021-01-01         3337357.0        105091.0
# ...        ...    ...       ...         ...               ...             ...
# 2759  Nordeste     AL       NaN  2021-12-31         3337357.0        242080.0
# 2023  Nordeste     CE       NaN  2021-12-31         9132078.0        956325.0
# 1839  Nordeste     PI       NaN  2021-12-31         3273227.0        334440.0
# 2391  Nordeste     PB       NaN  2021-12-31         4018127.0        464335.0
# 3127  Nordeste     BA       NaN  2021-12-31        14873064.0       1270858.0
#
# ...

# %% [markdown]
# # 3. ANÁLISE DOS DADOS

# %% [markdown]
# ### 3.1. 2021.1: percentual populacional de casos acumulados

# %% [markdown]
# #### Tabela demonstrando o percentual de casos acumulados em relação à população no último dia do semestre 2021.1 (30 de junho de 2021)

# %%
percentual_casos_20211 = (b2021_1_ultimo_dia['casosAcumulado']/b2021_1_ultimo_dia['populacaoTCU2019'])*100

estados = b2021_1_ultimo_dia['estado'].tolist()

populacao = b2021_1_ultimo_dia['populacaoTCU2019'].tolist()

casos_acumulados_20211 = b2021_1_ultimo_dia['casosAcumulado'].tolist()

dados_casos_acumulados_20211 = pd.DataFrame({
    'estados':estados, 
    'população em 2019': populacao, 
    'nº casos acumulados 2021.1': casos_acumulados_20211,
    'percentual casos x população':percentual_casos_20211.round(2)}).reset_index(drop=True)

dados_casos_acumulados_20211
# Out:
#   estados  população em 2019  nº casos acumulados 2021.1  \
# 0      AL          3337357.0                    216717.0
# 1      BA         14873064.0                   1124994.0
# 2      CE          9132078.0                    885980.0
# 3      MA          7075181.0                    317446.0
# 4      PB          4018127.0                    396442.0
# 5      PE          9557071.0                    550292.0
# 6      PI          3273227.0                    295781.0
# 7      RN          3506853.0                    340165.0
# 8      SE          2298696.0                    263512.0
#
#    percentual casos x população
# 0                          6.49
# 1                          7.56
# 2                          9.70
# 3                          4.49
# 4                          9.87
# 5                          5.76
# 6                          9.04
# 7                          9.70
# 8                         11.46

# %% [markdown]
# ### 3.2. 2021.1: percentual populacional de óbitos acumulados

# %% [markdown]
# #### Tabela demonstrando o percentual de óbitos acumulados em relação à população no último dia do semestre 2020.2 (31 de julho de 2020)

# %%
percentual_obitos_20211 = (b2021_1_ultimo_dia['obitosAcumulado']/b2021_1_ultimo_dia['populacaoTCU2019'])*100

obitos_acumulados_20211 = b2021_1_ultimo_dia['obitosAcumulado'].tolist()

dados_obitos_acumulados_20211 = pd.DataFrame({
    'estados':estados, 
    'população em 2019': populacao, 
    'nº óbitos acumulados 2021.1': obitos_acumulados_20211,
    'percentual óbitos x população':percentual_obitos_20211.round(2)}).reset_index(drop=True)

dados_obitos_acumulados_20211
# Out:
#   estados  população em 2019  nº óbitos acumulados 2021.1  \
# 0      AL          3337357.0                         5340
# 1      BA         14873064.0                        24012
# 2      CE          9132078.0                        22571
# 3      MA          7075181.0                         9043
# 4      PB          4018127.0                         8606
# 5      PE          9557071.0                        17685
# 6      PI          3273227.0                         6597
# 7      RN          3506853.0                         6768
# 8      SE          2298696.0                         5698
#
#    percentual óbitos x população
# 0                           0.16
# 1                           0.16
# 2                           0.25
# 3                           0.13
# 4                           0.21
# 5                           0.19
# 6                           0.20
# 7                           0.19
# 8                           0.25

# %% [markdown]
# ### 3.3. 2021.1: correlação entre dados

# %%
display(sns.heatmap(b2021_1_ultimo_dia.corr(numeric_only=True), cmap='inferno', annot=True))
# Out:
# <AxesSubplot: >

# %% [markdown]
# Ao final do primeiro semestre de 2021:
# - O número de casos acumulado tem forte correlação com o tamanho da população
# - O número de óbitos acumulado tem forte correlação com o tamanho da população
# - O número de óbitos novos tem forte correlação com o tamanho da população
# - O número acumulado de óbitos tem forte correlação com o número acumulado de casos

# %% [markdown]
# ### 3.4. 2021.2: percentual populacional de casos acumulados

# %% [markdown]
# #### Tabela demonstrando o percentual de casos acumulados em relação à população no último dia do semestre 2021.2 (31 de dezembro de 2021)

# %%
percentual_casos_20212 = (b2021_2_ultimo_dia['casosAcumulado']/b2021_2_ultimo_dia['populacaoTCU2019'])*100

estados = b2021_2_ultimo_dia['estado'].tolist()

populacao = b2021_2_ultimo_dia['populacaoTCU2019'].tolist()

casos_acumulados_20212 = b2021_2_ultimo_dia['casosAcumulado'].tolist()

dados_casos_acumulados_20212 = pd.DataFrame({
    'estados':estados, 
    'população em 2019': populacao, 
    'nº casos acumulados 2021.2': casos_acumulados_20212,
    'percentual casos x população':percentual_casos_20212.round(2)}).reset_index(drop=True)

dados_casos_acumulados_20212
# Out:
#   estados  população em 2019  nº casos acumulados 2021.2  \
# 0      AL          3337357.0                      242080
# 1      BA         14873064.0                     1270858
# 2      CE          9132078.0                      956325
# 3      MA          7075181.0                      370645
# 4      PB          4018127.0                      464335
# 5      PE          9557071.0                      645681
# 6      PI          3273227.0                      334440
# 7      RN          3506853.0                      387202
# 8      SE          2298696.0                      278530
#
#    percentual casos x população
# 0                          7.25
# 1                          8.54
# 2                         10.47
# 3                          5.24
# 4                         11.56
# 5                          6.76
# 6                         10.22
# 7                         11.04
# 8                         12.12

# %% [markdown]
# ### 3.5. 2021.2: percentual populacional de óbitos acumulados

# %% [markdown]
# #### Tabela demonstrando o percentual de óbitos acumulados em relação à população no último dia do semestre 2021.2 (31 de dezembro de 2021)

# %%
percentual_obitos_20212 = (b2021_2_ultimo_dia['obitosAcumulado']/b2021_2_ultimo_dia['populacaoTCU2019'])*100

obitos_acumulados_20212 = b2021_2_ultimo_dia['obitosAcumulado'].tolist()

dados_obitos_acumulados_20212 = pd.DataFrame({
    'estados':estados, 
    'população em 2019': populacao, 
    'nº óbitos acumulados 2021.2': obitos_acumulados_20212,
    'percentual óbitos x população':percentual_obitos_20212.round(2)}).reset_index(drop=True)

dados_obitos_acumulados_20212
# Out:
#   estados  população em 2019  nº óbitos acumulados 2021.2  \
# 0      AL          3337357.0                         6383
# 1      BA         14873064.0                        27506
# 2      CE          9132078.0                        24806
# 3      MA          7075181.0                        10377
# 4      PB          4018127.0                         9596
# 5      PE          9557071.0                        20447
# 6      PI          3273227.0                         7275
# 7      RN          3506853.0                         7572
# 8      SE          2298696.0                         6057
#
#    percentual óbitos x população
# 0                           0.19
# 1                           0.18
# 2                           0.27
# 3                           0.15
# 4                           0.24
# 5                           0.21
# 6                           0.22
# 7                           0.22
# 8                           0.26

# %% [markdown]
# ### 3.6. 2021.2: correlação entre dados

# %%
display(sns.heatmap(b2021_2_ultimo_dia.corr(numeric_only=True), cmap='inferno', annot=True))
# Out:
# <AxesSubplot: >

# %% [markdown]
# Ao final do segundo semestre de 2021:
# - O número de casos acumulados tem forte correlação com o tamanho da população
# - O número de óbitos acumulados tem forte correlação com o tamanho da população
# - O número de óbitos novos tem forte correlação com o número acumulado de casos
# - O número de óbitos acumulados tem forte correlação com o número acumulado de casos
# - O número acumulado de óbitos tem forte correlação com o número de óbitos novos

# %% [markdown]
# ### 3.7. 2021: aumento percentual de casos entre semestres

# %% [markdown]
# #### Tabela com o percentual de aumento do número de casos entre o final do primeiro e do segundo semestres de 2020

# %%
casos_2021_1 = b2021_1_ultimo_dia['casosAcumulado'].tolist()

casos_2021_2 = b2021_2_ultimo_dia['casosAcumulado'].tolist()

casos_1_2 = pd.DataFrame({
    'estados': estados,
    'número de casos 2021.1': casos_2021_1,
    'número de casos 2021.2': casos_2021_2})

percentual_aumento_casos = (casos_1_2['número de casos 2021.2']/casos_1_2['número de casos 2021.1'])*100

casos_1_2['percentual de aumento de casos'] = percentual_aumento_casos.round(2)

casos_1_2
# Out:
#   estados  número de casos 2021.1  número de casos 2021.2  \
# 0      AL                216717.0                  242080
# 1      BA               1124994.0                 1270858
# 2      CE                885980.0                  956325
# 3      MA                317446.0                  370645
# 4      PB                396442.0                  464335
# 5      PE                550292.0                  645681
# 6      PI                295781.0                  334440
# 7      RN                340165.0                  387202
# 8      SE                263512.0                  278530
#
#    percentual de aumento de casos
# 0                          111.70
# 1                          112.97
# 2                          107.94
# 3                          116.76
# 4                          117.13
# 5                          117.33
# 6                          113.07
# 7                          113.83
# 8                          105.70

# %% [markdown]
# ### 3.8. 2021: aumento percentual de óbitos entre semestres

# %% [markdown]
# #### Tabela com o percentual de aumento do número de óbitos entre o final do primeiro e do segundo semestres de 2020

# %%
obitos_2021_1 = b2021_1_ultimo_dia['obitosAcumulado'].tolist()

obitos_2021_2 = b2021_2_ultimo_dia['obitosAcumulado'].tolist()

obitos_1_2 = pd.DataFrame({
    'estados': estados,
    'número de casos 2021.1': obitos_2021_1,
    'número de casos 2021.2': obitos_2021_2})

percentual_aumento_obitos = (obitos_1_2['número de casos 2021.2']/obitos_1_2['número de casos 2021.1'])*100

obitos_1_2['percentual de aumento de óbitos'] = percentual_aumento_obitos.round(2)

obitos_1_2
# Out:
#   estados  número de casos 2021.1  número de casos 2021.2  \
# 0      AL                    5340                    6383
# 1      BA                   24012                   27506
# 2      CE                   22571                   24806
# 3      MA                    9043                   10377
# 4      PB                    8606                    9596
# 5      PE                   17685                   20447
# 6      PI                    6597                    7275
# 7      RN                    6768                    7572
# 8      SE                    5698                    6057
#
#    percentual de aumento de óbitos
# 0                           119.53
# 1                           114.55
# 2                           109.90
# 3                           114.75
# 4                           111.50
# 5                           115.62
# 6                           110.28
# 7                           111.88
# 8                           106.30

# %% [markdown]
# ### 3.9. 2021: gráfico do número acumulado de casos

# %% [markdown]
# #### Gráfico representando o número de casos acumulados no primeiro dia de cada mês do ano de 2021, de acordo com cada estado

# %%
grafico_casos_acumulados = xp.line(
    b2021_meses, 
    x='data', 
    y='casosAcumulado', 
    width=1000,
    color='estado',
    title='Casos acumulados - 2021')

grafico_casos_acumulados.show()

# %% [markdown]
# - Demonstra a forte correlação entre o número de casos e o tamanho da população (Bahia, Pernambuco e Ceará são os estados mais populosos).

# %%
grafico_percentual_casos = xp.bar(
    dados_casos_acumulados_20212, 
    x="estados",
    y="percentual casos x população",
    width=1000,
    title='Percentual de casos acumulados - 2021',
    color_discrete_sequence =['orange']*len(dados_casos_acumulados_20212))

grafico_percentual_casos.show()

# %% [markdown]
# - Normaliza o aumento de casos de acordo com o tamanho da população. Em 2021, Sergipe e Paraíba foram os estados com maior aumento de número de casos, confirmando que o alto número total de casos no gráfico de linhas para Bahia, Pernambuco e Ceará se dá pelo alto número populacional.

# %% [markdown]
# ### 3.10. 2021: gráfico do número acumulado de óbitos

# %% [markdown]
# #### Gráfico representando o número de óbitos acumulados no primeiro dia de cada mês do ano de 2021, de acordo com cada estado

# %%
grafico_obitos_acumulados = xp.line(
    b2021_meses, 
    x='data', 
    y='obitosAcumulado', 
    width=1000,
    color='estado',
    title='Óbitos acumulados - 2021')

grafico_obitos_acumulados.show()

# %% [markdown]
# - O gráfico demonstra a forte correlação entre o número acumulado de óbitos com o tamanho da população. Os três estados mais populosos do nordeste são Bahia, Pernambuco e Ceará.

# %%
grafico_percentual_obitos = xp.bar(
    dados_obitos_acumulados_20212, 
    x="estados",
    y="percentual óbitos x população",
    width=1000,
    title='Percentual de óbitos acumulados - 2021',
    color_discrete_sequence =['orange']*len(dados_obitos_acumulados_20212))

grafico_percentual_obitos.show()

# %% [markdown]
# - Normaliza o aumento de óbitos de acordo com o tamanho da população. Em 2021, Ceará, Sergipe e Paraíba foram os estados com maior aumento de número de casos, confirmando que o alto número total de óbitos no gráfico de linhas para Bahia, Pernambuco e Ceará se dá pelo alto número populacional.

# %% [markdown]
# ### 3.11. Gráfico de casos diários

# %%
grafico_casos_diarios = xp.line(
    b2021, x="data", y="casosNovos", facet_col="estado", facet_col_wrap=3,
              width=1000,
              height=1000,
              title="Casos Novos - 2021",
              color_discrete_sequence =['orange']*len(b2021))

grafico_casos_diarios.show()

# %%
fig_casos_box = xp.box(
    b2021, 
    y='casosNovos', 
    x='estado', 
    color_discrete_sequence =['orange']*len(b2021), 
    title='Casos novos - 2021',
    width=1000)

fig_casos_box.show()

# %% [markdown]
# ### 3.12. gráfico de óbitos diários

# %%
grafico_obitos_diarios = xp.line(
    b2021, x="data", 
    y="obitosNovos", 
    facet_col="estado", 
    facet_col_wrap=3,
    width=1000,
    height=1000,
    title="Óbitos Novos - 2021",
    color_discrete_sequence =['orange']*len(b2021))

grafico_obitos_diarios.show()

# %%
fig_obitos_box = xp.box(
    b2021, 
    y='obitosNovos', 
    x='estado', 
    color_discrete_sequence =['orange']*len(b2021), 
    title='Óbitos novos - 2021',
    width=1000)

fig_obitos_box.show()

# %% [markdown]
# ### 3.13. Alagoas

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_al = b2021_meses.loc[b2021_meses['estado']=='AL']
b2021_meses_al
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2534     AL  2021-01-01        105091.0         273             2496
# 2565     AL  2021-02-01        118220.0         452             2754
# 2593     AL  2021-03-01        132245.0         499             3010
# 2624     AL  2021-04-01        154199.0         709             3576
# 2654     AL  2021-05-01        174476.0         814             4240
# 2685     AL  2021-06-01        193581.0         535             4768
# 2576     AL  2021-07-01        217230.0         513             5360
# 2607     AL  2021-08-01        230069.0         109             5821
# 2638     AL  2021-09-01        235900.0         126             6078
# 2668     AL  2021-10-01        238249.0          39             6217
# 2699     AL  2021-11-01        240306.0         190             6294
# 2729     AL  2021-12-01        241513.0          23             6354
#
#       obitosNovos
# 2534            7
# 2565            8
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_al = b2021.loc[b2021['estado']=='AL']

fig_al = xp.bar(
    b2021_al, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Alagoas')

fig_al.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_al.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     376.060274
# obitosNovos     10.668493
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.14. Bahia

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_ba = b2021_meses.loc[b2021_meses['estado']=='BA']
b2021_meses_ba
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2896     BA  2021-01-01        494684.0        1284             9159
# 2927     BA  2021-02-01        589234.0        1128            10136
# 2955     BA  2021-03-01        686057.0        2020            11914
# 2986     BA  2021-04-01        808461.0        4797            15472
# 3016     BA  2021-05-01        905113.0        4272            18561
# 3047     BA  2021-06-01       1016480.0        4280            21329
# 2944     BA  2021-07-01       1128432.0        3438            24105
# 2975     BA  2021-08-01       1194316.0         627            25759
# 3006     BA  2021-09-01       1221597.0         805            26497
# 3036     BA  2021-10-01       1234370.0         571            26866
# 3067     BA  2021-11-01       1246439.0         143            27080
# 3097     BA  2021-12-01       1260931.0         590            27320
#
#       obitosNovos
# 2896           30
# 2927           39
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_ba = b2021.loc[b2021['estado']=='BA']

fig_ba = xp.bar(
    b2021_ba, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021- Bahia')

fig_ba.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_ba.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     2130.021918
# obitosNovos      50.347945
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.15. Ceará

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_ce = b2021_meses.loc[b2021_meses['estado']=='CE']
b2021_meses_ce
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 1810     CE  2021-01-01        335992.0         901             9993
# 1841     CE  2021-02-01        374856.0        1439            10477
# 1869     CE  2021-03-01        427148.0        1776            11293
# 1900     CE  2021-04-01        541227.0        2926            14167
# 1930     CE  2021-05-01        677152.0        9624            17767
# 1961     CE  2021-06-01        805134.0        3399            20587
# 1840     CE  2021-07-01        887774.0        1794            22627
# 1871     CE  2021-08-01        919462.0         256            23519
# 1902     CE  2021-09-01        931803.0         482            24027
# 1932     CE  2021-10-01        940756.0         293            24233
# 1963     CE  2021-11-01        943675.0          11            24497
# 1993     CE  2021-12-01        951141.0        1341            24664
#
#       obitosNovos
# 1810            3
# 1841            1
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_ce = b2021.loc[b2021['estado']=='CE']

fig_ce = xp.bar(
    b2021_ce, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Ceará')

fig_ce.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_ce.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     1702.010959
# obitosNovos      40.591781
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.16. Maranhão

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_ma = b2021_meses.loc[b2021_meses['estado']=='MA']
b2021_meses_ma
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 1448     MA  2021-01-01        200959.0          21             4506
# 1479     MA  2021-02-01        207649.0         161             4708
# 1507     MA  2021-03-01        219632.0         325             5074
# 1538     MA  2021-04-01        243720.0        1319             6108
# 1568     MA  2021-05-01        267548.0         638             7311
# 1599     MA  2021-06-01        291373.0        1074             8160
# 1472     MA  2021-07-01        318394.0         948             9065
# 1503     MA  2021-08-01        337153.0          37             9641
# 1534     MA  2021-09-01        349537.0         473            10040
# 1564     MA  2021-10-01        356562.0         326            10177
# 1595     MA  2021-11-01        361099.0          22            10238
# 1625     MA  2021-12-01        365338.0         290            10297
#
#       obitosNovos
# 1448            6
# 1479           11
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_ma = b2021.loc[b2021['estado']=='MA']

fig_ma = xp.bar(
    b2021_ma, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Maranhão')

fig_ma.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_ma.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     464.950685
# obitosNovos     16.101370
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.17. Paraíba

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_pb = b2021_meses.loc[b2021_meses['estado']=='PB']
b2021_meses_pb
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2172     PB  2021-01-01        167062.0         578             3680
# 2203     PB  2021-02-01        192598.0        1014             4068
# 2231     PB  2021-03-01        222259.0        1144             4526
# 2262     PB  2021-04-01        260484.0        1311             5791
# 2292     PB  2021-05-01        293717.0        1048             6819
# 2323     PB  2021-06-01        332716.0        1751             7703
# 2208     PB  2021-07-01        396904.0         462             8628
# 2239     PB  2021-08-01        422543.0         495             8994
# 2270     PB  2021-09-01        433729.0         407             9190
# 2300     PB  2021-10-01        441837.0         163             9312
# 2331     PB  2021-11-01        446066.0          55             9423
# 2361     PB  2021-12-01        460909.0         329             9532
#
#       obitosNovos
# 2172            8
# 2203           12
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_pb = b2021.loc[b2021['estado']=='PB']

fig_pb = xp.bar(
    b2021_pb, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Paraíba')

fig_pb.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_pb.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     816.030137
# obitosNovos     16.230137
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.18. Pernambuco

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_pe = b2021_meses.loc[b2021_meses['estado']=='PE']
b2021_meses_pe
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2353     PE  2021-01-01        222993.0         827             9666
# 2384     PE  2021-02-01        261745.0         445            10364
# 2412     PE  2021-03-01        300104.0         629            11007
# 2443     PE  2021-04-01        352218.0        2987            12249
# 2473     PE  2021-05-01        408763.0        2178            14128
# 2504     PE  2021-06-01        485594.0        3437            15940
# 2392     PE  2021-07-01        552289.0        1997            17720
# 2423     PE  2021-08-01        591428.0         643            18808
# 2454     PE  2021-09-01        608586.0        1057            19411
# 2484     PE  2021-10-01        621192.0         469            19747
# 2515     PE  2021-11-01        632011.0         119            20025
# 2545     PE  2021-12-01        640158.0         421            20253
#
#       obitosNovos
# 2353           12
# 2384           16
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_pe = b2021.loc[b2021['estado']=='PE']

fig_pe = xp.bar(
    b2021_pe, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Pernambuco')

fig_pe.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_pe.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     1160.315068
# obitosNovos      29.569863
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.19. Rio Grande do Norte

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_rn = b2021_meses.loc[b2021_meses['estado']=='RN']
b2021_meses_rn
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 1991     RN  2021-01-01        118353.0         270             2993
# 2022     RN  2021-02-01        140704.0         121             3288
# 2050     RN  2021-03-01        167429.0         534             3608
# 2081     RN  2021-04-01        197076.0         815             4548
# 2111     RN  2021-05-01        224245.0        1270             5483
# 2142     RN  2021-06-01        269685.0        1259             6149
# 2024     RN  2021-07-01        343352.0        3187             6797
# 2055     RN  2021-08-01        359776.0         111             7097
# 2086     RN  2021-09-01        365177.0         144             7269
# 2116     RN  2021-10-01        368716.0          97             7340
# 2147     RN  2021-11-01        373693.0           9             7399
# 2177     RN  2021-12-01        382003.0         300             7499
#
#       obitosNovos
# 1991            0
# 2022            3
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_rn = b2021.loc[b2021['estado']=='RN']

fig_rn = xp.bar(
    b2021_rn, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Rio Grande do Norte')

fig_rn.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_rn.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     737.312329
# obitosNovos     12.545205
# Name: mean, dtype: float64

# %% [markdown]
# ### 3.20. Sergipe

# %% [markdown]
# #### Dados referentes ao primeiro dia de cada mês de 2021

# %%
b2021_meses_se = b2021_meses.loc[b2021_meses['estado']=='SE']
b2021_meses_se
# Out:
#      estado        data  casosAcumulado  casosNovos  obitosAcumulado  \
# 2715     SE  2021-01-01        113544.0        1039             2492
# 2746     SE  2021-02-01        138187.0         770             2786
# 2774     SE  2021-03-01        152003.0         592             2969
# 2805     SE  2021-04-01        175582.0         982             3525
# 2835     SE  2021-05-01        203036.0        1257             4302
# 2866     SE  2021-06-01        238276.0        1371             5114
# 2760     SE  2021-07-01        264213.0         701             5714
# 2791     SE  2021-08-01        274595.0         333             5915
# 2822     SE  2021-09-01        277470.0          15             5995
# 2852     SE  2021-10-01        278134.0          30             6010
# 2883     SE  2021-11-01        278504.0           6             6031
# 2913     SE  2021-12-01        278266.0          41             6044
#
#       obitosNovos
# 2715            8
# 2746            8
# ...

# %% [markdown]
# #### Gráfico do número de casos e óbitos do estado em 2021

# %%
b2021_se = b2021.loc[b2021['estado']=='SE']

fig_se = xp.bar(
    b2021_se, 
    x='data', 
    y='casosNovos', 
    width=1000, 
    color='obitosNovos',
    color_discrete_sequence ='inferno',
    title='Casos e óbitos no ano 2021 - Sergipe')

fig_se.show()

# %% [markdown]
# #### Média anual de casos e óbitos:

# %%
b2021_se.describe().iloc[1, [2, 4]]
# Out:
# casosNovos     454.863014
# obitosNovos      9.789041
# Name: mean, dtype: float64

# %% [markdown]
# # 4. SALVANDO EM CSV

# %% [markdown]
# - Para análise dos anos 2020, 2021, 2022

# %% [markdown]
# ### 4.1. Dados semestrais

# %%
b2021_1_ultimo_dia.to_csv('covid_2021_1.csv', index=False)

# %%
b2021_2_ultimo_dia.to_csv('covid_2021_2.csv', index=False)

# %% [markdown]
# ### 4.2. Dados mensais

# %%
b2021_meses.to_csv('covid_2021_mensal.csv', index=False)
